# %% [markdown]
# Recopilación Datos
#
# Tomaremos datos y los guardaremos en un csv siempre que los resultados tengan un error relativo menor a 0.1%

# %%
using LinearAlgebra
using DifferentialEquations
using DelimitedFiles

function phi(Point1::Array{Float64, 1}, Point2::Array{Float64, 1}, v_wind::Array{Float64, 1}, tau) 
            #tgphi= (Point2[2]-Point1[2]- v_wind[2]*tau)/(Point2[1]-Point1[1]- v_wind[1]*tau) #Cálculo phi primera iteración
            #phi=rad2deg(atan(tgphi))
            phi=rad2deg(atan((Point2[2]-Point1[2]- v_wind[2]*tau),(Point2[1]-Point1[1]- v_wind[1]*tau)))
            return phi
end
function Slowness_Spherical(Point1::Array{Float64, 1}, Point2::Array{Float64, 1}, v_wind::Array{Float64, 1}, phi, c_source)
    x1,y1,z1=Point2-Point1 #Obtención parámetros primera iteración
    r=norm(Point2-Point1)
    theta=rad2deg(acos(z1/r))
    q0=1/(c_source + (v_wind[1]*cosd(phi)+ v_wind[2]*sind(phi))*cosd(theta) )
    qx=q0*cosd(phi)*sind(theta)
    qy=q0*sind(phi)*sind(theta)
    qz=q0*cosd(theta)
    return q0,qx,qy,qz,theta
end
function c_z(T,z) 
    if z>0
        c_air=331*sqrt((T+273.15-z/200)/273.15) #Modelo termodinámico v_sonido.Introduzco T_Z0 en grados centígrados por comodidad
    else
        c_air=331*sqrt((T+273.15)/273.15)
    end
    return c_air
end
function g!(dg, g, p, t)
    qx,qy = p
    q_aux = sqrt(qx^2 + qy^2 + g[4]^2)
    c=c_z(T,g[3])
    dg[1] = c*qx/q_aux + v_wind[1] #Variación coordenada X
    dg[2] = c*qy/q_aux + v_wind[2]  #Variación coordenada Y
    dg[3] = c*g[4]/q_aux + v_wind[3] #Variación coordenada Z
    dg[4]=+q_aux*(331^2/(400*273.15))/c #Variación qz
end


E_rel_ideal=  0.01
v_wind = [-20 + (20 - (-20)) * rand(),-20 + (20 - (-20)) * rand(),-20 + (20 - (-20)) * rand()]
Source = [10000 * rand(), 10000 * rand() , 10000 * rand()]
Receiver = [10000 * rand(), 10000 * rand() , 10000 * rand()]
T = rand(-20.:40.)

#### Necesitamos una velocidad inicial, correspondiente a la fuente, y un ángulo azimutal para empezar a iterar.
c_source=c_z(T, Source[3])
####
R=norm(Receiver-Source)
t_min=R/c_z(T,min(Source[3],Receiver[3]))
t_max=R/c_z(T, max(Source[3],Receiver[3]))
phi1=phi(Source,Receiver,v_wind, t_max) #Acotación teórica phi
phi2=phi(Source,Receiver,v_wind, t_min) #Acotación teórica phi
phi_i=(phi1+phi2)/2 #La media de la cota de phi como phi para la primera iteración
#######
q0,q_x,q_y,q_z,theta_i=Slowness_Spherical(Source,Receiver,v_wind, phi_i, c_source) #Obtención parámetros
theta_recta=deepcopy(theta_i)
#######
traveltime=[]
detener = 0 # Variable de control
for l in 1:15
    if detener==1
        break
    end     
    thetas= range(theta_i-45/(2^(l-1)), theta_i+45/(2^(l-1)), 50);
    if v_wind[1:2]==[0.,0.]
            phis=[deepcopy(phi_i)]
    else
        if l==1
            phis=(min(phi1,phi2):0.05:max(phi1,phi2))
        else
            phi_distance=max(phi1,phi2)-min(phi1,phi2)
            phis= range(phi_i-phi_distance/(2^(l)), theta_i-phi_distance/(2^(l)), 20);
        end
    end
    angulos_theta = []
    angulos_phi = []
    tiempos = []
    for i in 1:length(thetas)
        for j in 1:length(phis)
            if l>1
                q0=1/(c_source + (v_wind[1]*cosd(phi_i)+ v_wind[2]*sind(phi_i))*cosd(theta_i) )
            end
            q_x=q0*cosd(phis[j])*sind(thetas[i])
            q_y=q0*sind(phis[j])*sind(thetas[i])
            q_z=q0*cosd(thetas[i])
            p = [q_x, q_y]
            u0 = [Source[1],Source[2],Source[3], q_z]
            tspan=[0,t_max]
            prob = ODEProblem(g!, u0, tspan, p)
            paso=1e-2*R/2000
            sol = solve(prob, RK4(), dt=paso, saveat=0:paso:t_max)
            for k in 1:length(sol.u)
                if detener==0
                    if sqrt((sol.u[k][1] - Receiver[1])^2 +(sol.u[k][2] - Receiver[2])^2 + (sol.u[k][3] - Receiver[3])^2 ) < R/(20*2^(l-1))
                        push!(angulos_theta, thetas[i])
                        push!(angulos_phi, phis[j])
                        push!(tiempos, sol.t[k])
                        break
                    elseif sqrt((sol.u[k][1] - Receiver[1])^2 +(sol.u[k][2] - Receiver[2])^2 + (sol.u[k][3] - Receiver[3])^2 ) < R*E_rel_ideal/100
                        traveltime = sol.t[k] #Error relativo menor a 0.01% ya detenemos el barrido
                        theta_i = thetas[i]
                        phi_i = phis[j]
                        detener = 1 # Cambiamos el valor de la variable de control
                        println("Se alcanzó el error relativo objetivo.")
                        break
                    end
                else
                    break
                end
            end
        end
    end
    if length(tiempos)==0
        if l==1
            println("No se encontró ninguna trayectoria entre fuente y receptor. Valora si estás en una zona de sombra o ajusta el paso de tiempo ")
        end
        break
    elseif detener==0
        traveltime = findmin(tiempos)
        indice = argmin(tiempos)
        theta_i=angulos_theta[indice]
        phi_i=angulos_phi[indice]
    end
end
q_x=q0*cosd(phi_i)*sind(theta_i)
q_y=q0*sind(phi_i)*sind(theta_i)
q_z=q0*cosd(theta_i)
# Definir los parámetros
p = [q_x, q_y]
u0 = [Source[1],Source[2], Source[3], q_z]
tspan=[0,traveltime[1]]
# Crear el problema ODE
prob = ODEProblem(g!, u0, tspan, p)
# Resolver el problema ODE
paso=1e-2*R/2000
sol = solve(prob, RK4(), dt=paso, saveat=0:paso:traveltime[1])
println("El traveltime es: ", traveltime[1], " s.") 
println("Se reconstruye la trayectoria con ángulos de emisión: polar θ=", theta_i, "º y azimutal φ=", phi_i, "º.")
error_relativo=(sqrt((sol.u[end][1] - Receiver[1])^2 +(sol.u[end][2] - Receiver[2])^2 + (sol.u[end][3] - Receiver[3])^2 )/R)*100
println("El error relativo es del ", error_relativo, " %.")
#### Datos a recopilar
Delta_X=Receiver[1]-Source[1]
Delta_Y=Receiver[2]-Source[2]
Delta_Z=Receiver[3]-Source[3]
W_X=v_wind[1]
W_Y=v_wind[2]
W_Z=v_wind[3]
Delta_Theta=theta_i-theta_recta
phi_recta=phi(Source,Receiver,v_wind, traveltime[1])
Delta_phi=phi_i-phi_recta
####
if error_relativo<0.2  #Es en tanto por ciento 
    new_row=[Source[1],Source[2],Source[3],Delta_X, Delta_Y, Delta_Z, W_X, W_Y, W_Z, T, phi_recta , phi_i, Delta_phi, theta_recta, theta_i, Delta_Theta, error_relativo]
  # Convierte la fila en un array bidimensional
    new_row_2d = reshape(new_row, 1, length(new_row))
    # Añade la nueva fila al archivo
    open("C:\\Users\\Miguel\\Desktop\\TFM\\Recopilación_Datos.txt", "a") do io
        writedlm(io, new_row_2d, ',')
    end
end
# Out:
# El traveltime es: 9.102595705083049 s.
# Se reconstruye la trayectoria con ángulos de emisión: polar θ=116.9324489231651º y azimutal φ=-38.24003189453898º.
# El error relativo es del 4.880226977300053 %.

# %% [markdown]
# No encontró ninguna trayectoria para Source=[6455,8184,6252], Receiver=[2986,9823,6306],v_wind=[11,-13,3], T=24
# No encontró ninguna trayectoria para Source=[4427,6774,5789], Receiver=[6906,2379,5206],v_wind=[-16,19,-11], T=-18

# %% [markdown]
# Tenemos 172 datos para entrenar el modelo. Dado que theta y phi correspondientes a la línea recta se pueden conocer del resto de características, las eliminamos para el entrenamiento. Además, la columna correspondiente al error relativo nos da una idea de la validez de cada dato de entrenamiento, por lo que podemos asociar un peso a cada fila de 1-E_rel

# %%
using Pkg
Pkg.add("MLJ") #Machine Learning para Julia
Pkg.add("GLM")
Pkg.add("MLJModels")
Pkg.add("MLJGLMInterface")
Pkg.add("MLJMultivariateStatsInterface")
Pkg.add("DecisionTree")
Pkg.add("MLJDecisionTreeInterface")
Pkg.add("EvoTrees")
Pkg.add("Distributions")
# Out:
#     Updating registry at `C:\Users\Miguel\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed EarlyStopping ──────────── v0.3.0
#    Installed Libuuid_jll ────────────── v2.40.1+0
#    Installed Expat_jll ──────────────── v2.6.2+0
#    Installed StatisticalTraits ──────── v3.2.0
#    Installed Cairo_jll ──────────────── v1.18.0+2
#    Installed InverseFunctions ───────── v0.1.14
#    Installed OpenEXR_jll ────────────── v3.2.4+0
#    Installed Xorg_libICE_jll ────────── v1.1.1+0
#    Installed MLJModels ──────────────── v0.16.17
#    Installed ScientificTypesBase ────── v3.0.0
#    Installed MLJTuning ──────────────── v0.7.4
#    Installed StrideArraysCore ───────── v0.5.6
#    Installed FixedPointNumbers ──────── v0.8.5
#    Installed RecursiveFactorization ─── v0.2.22
#    Installed IntervalArithmetic ─────── v0.22.11
#    Installed LatinHypercubeSampling ─── v1.9.0
#    Installed JpegTurbo_jll ──────────── v3.0.3+0
#    Installed Libmount_jll ───────────── v2.40.1+0
#    Installed Polyester ──────────────── v0.7.14
#    Installed IntelOpenMP_jll ────────── v2024.1.0+0
#    Installed LossFunctions ──────────── v0.11.1
#    Installed Fontconfig_jll ─────────── v2.13.96+0
#    Installed SIMD ───────────────────── v3.5.0
#    Installed PtrArrays ──────────────── v1.1.0
#    Installed TranscodingStreams ─────── v0.10.8
#    Installed Xorg_libXext_jll ───────── v1.3.6+0
#    Installed FriBidi_jll ────────────── v1.0.14+0
#    Installed Compat ─────────────────── v4.15.0
#    Installed Imath_jll ──────────────── v3.1.11+0
#    Installed MLJIteration ───────────── v0.5.1
#    Installed LoopVectorization ──────── v0.12.170
#    Installed AliasTables ────────────── v1.1.3
#    Installed CPUSummary ─────────────── v0.2.5
#    Installed StableRNGs ─────────────── v1.0.2
#    Installed ColorSchemes ───────────── v3.25.0
#    Installed ImageIO ────────────────── v0.6.8
#    Installed ScientificTypes ────────── v3.0.2
#    Installed FillArrays ─────────────── v1.11.0
#    Installed SparseDiffTools ────────── v2.18.0
#    Installed GeoInterface ───────────── v1.3.4
#    Installed TiffImages ─────────────── v0.10.0
#    Installed Krylov ─────────────────── v0.9.6
#    Installed MLJ ────────────────────── v0.19.2
#    Installed Libgpg_error_jll ───────── v1.49.0+0
#    Installed Unitful ────────────────── v1.19.1
#    Installed oneTBB_jll ─────────────── v2021.12.0+0
#    Installed JLD2 ───────────────────── v0.4.47
#    Installed PrettyPrinting ─────────── v0.4.2
#    Installed ArrayLayouts ───────────── v1.9.2
#    Installed DataStructures ─────────── v0.18.20
#    Installed IterationControl ───────── v0.5.4
#    Installed Colors ─────────────────── v0.12.11
#    Installed MathOptInterface ───────── v1.29.0
#    Installed Libgcrypt_jll ──────────── v1.8.11+0
#    Installed Glib_jll ───────────────── v2.80.2+0
#    Installed VectorizationBase ──────── v0.21.67
#    Installed GeometryBasics ─────────── v0.4.11
#    Installed LittleCMS_jll ──────────── v2.16.0+0
#    Installed OpenML ─────────────────── v0.3.1
#    Installed Latexify ───────────────── v0.16.3
#    Installed Distributions ──────────── v0.25.108
#    Installed MutableArithmetics ─────── v1.4.4
#    Installed Permutations ───────────── v0.4.21
#    Installed OffsetArrays ───────────── v1.14.0
#    Installed Xorg_libSM_jll ─────────── v1.2.4+0
#    Installed SentinelArrays ─────────── v1.4.2
#    Installed LZO_jll ────────────────── v2.10.2+0
#    Installed CategoricalDistributions ─ v0.1.15
#    Installed ZMQ ────────────────────── v1.2.3
#    Installed MKL_jll ────────────────── v2024.1.0+0
#    Installed Xorg_libXrender_jll ────── v0.9.11+0
#    Installed KernelDensity ──────────── v0.6.9
#    Installed MLJEnsembles ───────────── v0.3.3
#    Installed FastLapackInterface ────── v2.0.3
#    Installed ARFFFiles ──────────────── v1.4.1
#    Installed Pixman_jll ─────────────── v0.43.4+0
#    Installed MLJBase ────────────────── v0.21.14
#    Installed MLJModelInterface ──────── v1.9.6
#    Installed OpenJpeg_jll ───────────── v2.5.2+0
#    Installed LAME_jll ───────────────── v3.100.2+0
#     Updating `C:\Users\Miguel\.julia\environments\v1.9\Project.toml`
# ⌃ [add582a8] + MLJ v0.19.2
#     Updating `C:\Users\Miguel\.julia\environments\v1.9\Manifest.toml`
#   [da404889] + ARFFFiles v1.4.1
#   [66dad0bd] + AliasTables v1.1.3
#   [4c555306] ↑ ArrayLayouts v1.9.1 ⇒ v1.9.2
#   [2a0fbf3d] ↑ CPUSummary v0.2.4 ⇒ v0.2.5
#   [af321ab8] + CategoricalDistributions v0.1.15
#   [35d6a980] ↑ ColorSchemes v3.24.0 ⇒ v3.25.0
#   [5ae59095] ↑ Colors v0.12.10 ⇒ v0.12.11
#   [34da2185] ↑ Compat v4.14.0 ⇒ v4.15.0
#   [864edb3b] ↑ DataStructures v0.18.18 ⇒ v0.18.20
#   [31c24e10] ↑ Distributions v0.25.107 ⇒ v0.25.108
#   [792122b4] + EarlyStopping v0.3.0
#   [29a986be] ↑ FastLapackInterface v2.0.2 ⇒ v2.0.3
#   [1a297f60] ↑ FillArrays v1.10.0 ⇒ v1.11.0
#   [53c48c17] ↑ FixedPointNumbers v0.8.4 ⇒ v0.8.5
#   [cf35fbd7] ↑ GeoInterface v1.3.3 ⇒ v1.3.4
#   [5c1252a2] ↑ GeometryBasics v0.4.10 ⇒ v0.4.11
#   [82e4d734] ↑ ImageIO v0.6.7 ⇒ v0.6.8
#   [d1acc4aa] ↑ IntervalArithmetic v0.22.10 ⇒ v0.22.11
#   [3587e190] ↑ InverseFunctions v0.1.13 ⇒ v0.1.14
#   [b3c1a2ee] + IterationControl v0.5.4
#   [033835bb] ↑ JLD2 v0.4.46 ⇒ v0.4.47
#   [5ab0869b] ↑ KernelDensity v0.6.8 ⇒ v0.6.9
#   [ba0b0d4f] ↑ Krylov v0.9.5 ⇒ v0.9.6
#   [23fbe1c1] ↑ Latexify v0.16.2 ⇒ v0.16.3
#   [a5e1c1ea] + LatinHypercubeSampling v1.9.0
#   [bdcacae8] ↑ LoopVectorization v0.12.169 ⇒ v0.12.170
#   [30fc2ffe] + LossFunctions v0.11.1
# ⌃ [add582a8] + MLJ v0.19.2
# ⌅ [a7f614a8] + MLJBase v0.21.14
# ⌅ [50ed68f4] + MLJEnsembles v0.3.3
# ⌅ [614be32b] + MLJIteration v0.5.1
#   [e80e1ace] + MLJModelInterface v1.9.6
#   [d491faf4] + MLJModels v0.16.17
# ⌅ [03970b2e] + MLJTuning v0.7.4
#   [b8f27783] ↑ MathOptInterface v1.27.1 ⇒ v1.29.0
#   [d8a4904e] ↑ MutableArithmetics v1.4.2 ⇒ v1.4.4
#   [6fe1bfb0] ↑ OffsetArrays v1.13.0 ⇒ v1.14.0
#   [8b6db2d4] + OpenML v0.3.1
#   [2ae35dd2] ↑ Permutations v0.4.20 ⇒ v0.4.21
#   [f517fe37] ↑ Polyester v0.7.12 ⇒ v0.7.14
#   [54e16d92] + PrettyPrinting v0.4.2
#   [43287f4e] + PtrArrays v1.1.0
# ⌅ [f2c3362d] ↑ RecursiveFactorization v0.2.21 ⇒ v0.2.22
#   [fdea26ae] + SIMD v3.5.0
#   [321657f4] + ScientificTypes v3.0.2
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [91c51154] ↑ SentinelArrays v1.4.1 ⇒ v1.4.2
# ⌅ [47a9eef4] ↑ SparseDiffTools v2.17.0 ⇒ v2.18.0
#   [860ef19b] + StableRNGs v1.0.2
#   [64bff920] + StatisticalTraits v3.2.0
#   [7792a7ef] ↑ StrideArraysCore v0.5.2 ⇒ v0.5.6
#   [731e570b] ↑ TiffImages v0.6.8 ⇒ v0.10.0
#   [3bb67fe8] ↑ TranscodingStreams v0.10.7 ⇒ v0.10.8
#   [1986cc42] ↑ Unitful v1.19.0 ⇒ v1.19.1
#   [3d5dd08c] ↑ VectorizationBase v0.21.65 ⇒ v0.21.67
#   [c2297ded] ↑ ZMQ v1.2.2 ⇒ v1.2.3
#   [83423d85] ↑ Cairo_jll v1.18.0+1 ⇒ v1.18.0+2
#   [2e619515] ↑ Expat_jll v2.5.0+0 ⇒ v2.6.2+0
#   [a3f928ae] ↑ Fontconfig_jll v2.13.93+0 ⇒ v2.13.96+0
#   [559328eb] ↑ FriBidi_jll v1.0.10+0 ⇒ v1.0.14+0
#   [7746bdde] ↑ Glib_jll v2.80.0+0 ⇒ v2.80.2+0
#   [905a6f67] ↑ Imath_jll v3.1.7+0 ⇒ v3.1.11+0
#   [1d5cc7b8] ↑ IntelOpenMP_jll v2024.0.2+0 ⇒ v2024.1.0+0
#   [aacddb02] ↑ JpegTurbo_jll v3.0.2+0 ⇒ v3.0.3+0
#   [c1c5ebd0] ↑ LAME_jll v3.100.1+0 ⇒ v3.100.2+0
#   [dd4b983a] ↑ LZO_jll v2.10.1+0 ⇒ v2.10.2+0
#   [d4300ac3] ↑ Libgcrypt_jll v1.8.7+0 ⇒ v1.8.11+0
#   [7add5ba3] ↑ Libgpg_error_jll v1.42.0+0 ⇒ v1.49.0+0
#   [4b2f31a3] ↑ Libmount_jll v2.39.3+0 ⇒ v2.40.1+0
#   [38a345b3] ↑ Libuuid_jll v2.39.3+1 ⇒ v2.40.1+0
#   [d3a379c0] ↑ LittleCMS_jll v2.15.0+0 ⇒ v2.16.0+0
#   [856f044c] ↑ MKL_jll v2024.0.0+0 ⇒ v2024.1.0+0
#   [18a262bb] ↑ OpenEXR_jll v3.1.4+0 ⇒ v3.2.4+0
#   [643b3616] ↑ OpenJpeg_jll v2.5.0+0 ⇒ v2.5.2+0
#   [30392449] ↑ Pixman_jll v0.42.2+0 ⇒ v0.43.4+0
#   [f67eecfb] ↑ Xorg_libICE_jll v1.0.10+1 ⇒ v1.1.1+0
#   [c834827a] ↑ Xorg_libSM_jll v1.2.3+0 ⇒ v1.2.4+0
#   [1082639a] ↑ Xorg_libXext_jll v1.3.4+4 ⇒ v1.3.6+0
#   [ea2f1a96] ↑ Xorg_libXrender_jll v0.9.10+4 ⇒ v0.9.11+0
#   [1317d2d5] + oneTBB_jll v2021.12.0+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Permutations
#   ✓ ScientificTypesBase
#   ✓ FillArrays
#   ✓ OffsetArrays
#   ✓ SentinelArrays
#   ✓ Compat
#   ✓ InverseFunctions
#   ✓ EarlyStopping
#   ✓ StableRNGs
#   ✓ PtrArrays
#   ✓ PrettyPrinting
#   ✓ TranscodingStreams
#   ✓ FastLapackInterface
#   ✓ MutableArithmetics
#   ✓ Latexify
#   ✓ LossFunctions
#   ✓ GeoInterface
#   ✓ Krylov
#   ✓ Libmount_jll
#   ✓ FixedPointNumbers
#   ✓ CPUSummary
#   ✓ Xorg_libICE_jll
#   ✓ Imath_jll
#   ✓ IntelOpenMP_jll
#   ✓ LAME_jll
#   ✓ Pixman_jll
#   ✓ JpegTurbo_jll
#   ✓ oneTBB_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Libgpg_error_jll
#   ✓ Libuuid_jll
#   ✓ FriBidi_jll
#   ✓ StatisticalTraits
#   ✓ ZMQ
#   ✓ FillArrays → FillArraysPDMatsExt
#   ✓ IntervalArithmetic
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ InverseFunctions → DatesExt
#   ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#   ✓ SIMD
#   ✓ AliasTables
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ LossFunctions → LossFunctionsCategoricalArraysExt
#   ✓ TranscodingStreams → TestExt
#   ✓ IterationControl
#   ✓ Glib_jll
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✓ PolyesterWeave
#   ✓ Xorg_libSM_jll
#   ✓ OpenEXR_jll
#   ✓ ColorTypes
#   ✓ Libtiff_jll
#   ✓ libsixel_jll
#   ✓ Libgcrypt_jll
#   ✓ MLJModelInterface
#   ✓ Fontconfig_jll
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ FilePathsBase
#   ✓ DataStructures
#   ✓ ChainRulesCore
#   ✓ StableHashTraits
#   ✓ StackViews
#   ✓ Sparspak
#   ✓ PaddedViews
#   ✓ CatIndices
#   ✓ CodecZlib
#   ✓ ARFFFiles
#   ✓ Accessors
#   ✓ CodecBzip2
#   ✓ IntegralArrays
#   ✓ Colors
#   ✓ Unitful
#   ✓ QOI
#   ✓ LittleCMS_jll
#   ✓ XSLT_jll
#   ✓ FilePaths
#   ✓ MKL_jll
#   ✓ SortingAlgorithms
#   ✓ Automa
#   ✓ SimplePartitions
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ QuadGK
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ MosaicViews
#   ✓ WriteVTK
#   ✓ OpenML
#   ✓ ArrayLayouts
#   ✓ Accessors → AccessorsIntervalSetsExt
#   ✓ Graphics
#   ✓ Animations
#   ✓ Widgets
#   ✓ JLD2
#   ✓ ColorBrewer
#   ✓ PyPlot
#   ✓ OpenEXR
#   ✓ OpenJpeg_jll
#   ✓ Unitful → InverseFunctionsUnitfulExt
#   ✓ Compose
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ ZygoteRules
#   ✓ Interpolations
#   ✓ HCubature
#   ✓ GeometryBasics
#   ✓ CSV
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ Graphs
#   ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#   ✓ Accessors → AccessorsStructArraysExt
#   ✓ ImageMagick_jll
#   ✓ LightGraphs
#   ✓ WebIO
#   ✓ Unitful → ConstructionBaseUnitfulExt
#   ✓ Cairo_jll
#   ✓ Qt6Base_jll
#   ✓ Interpolations → InterpolationsUnitfulExt
#   ✓ Packing
#   ✓ ShaderAbstractions
#   ✓ MeshIO
#   ✓ StatsBase
#   ✓ GridLayoutBase
#   ✓ SpecialFunctions
#   ✓ MetaGraphs
#   ✓ VertexSafeGraphs
#   ✓ SimpleWeightedGraphs
#   ✓ GraphPlot
#   ✓ BlockArrays
#   ✓ Accessors → AccessorsStaticArraysExt
#   ✓ JSExpr
#   ✓ CSSUtil
#   ✓ HarfBuzz_jll
#   ✓ LatinHypercubeSampling
#   ✓ Clustering
#   ✓ CoupledFields
#   ✓ FastGaussQuadrature
#   ✓ LevyArea
#   ✓ DualNumbers
#   ✓ ColorVectorSpace
#   ✓ ForwardDiff
#   ✓ BandedMatrices
#   ✓ Accessors → AccessorsUnitfulExt
#   ✓ Knockout
#   ✓ libass_jll
#   ✓ Blink
#   ✓ HypergeometricFunctions
#   ✓ DataFrames
#   ✓ PolynomialBases
#   ✓ FreeTypeAbstraction
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ ColorSchemes
#   ✓ TiffImages
#   ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#   ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   ✓ FFMPEG_jll
#   ✓ Roots
#   ✓ InteractBase
#   ✓ StatsFuns
#   ✓ Latexify → DataFramesExt
#   ✓ MathTeXEngine
#   ✓ PlotlyBase
#   ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#   ✓ PreallocationTools
#   ✓ StaticArrayInterface
#   ✓ SciMLBase
#   ✓ PlotUtils
#   ✓ FFMPEG
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   ✓ GR_jll
#   ✓ ImageCore
#   ✓ Roots → RootsForwardDiffExt
#   ✓ Interact
#   ✓ UnitfulLatexify
#   ✓ StatsFuns → StatsFunsInverseFunctionsExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ PlotlyJS
#   ✓ ExactPredicates
#   ✓ PlotThemes
#   ✓ NLSolversBase
#   ✓ RecipesPipeline
#   ✓ GR
#   ✓ ImageBase
#   ✓ JpegTurbo
#   ✓ PNGFiles
#   ✓ ImageMagick
#   ✓ Sixel
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ PlotlyJS → CSVExt
#   ✓ LineSearches
#   ✓ Distributions
#   ✓ HistogramThresholding
#   ✓ ImageTransformations
#   ✓ ImageAxes
#   ✓ TiledIteration
#   ✓ ImageShow
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ SparseDiffTools
#   ✓ NLsolve
#   ✓ PlotlyJS → DataFramesExt
#   ✓ ImageBinarization
#   ✓ Distributions → DistributionsTestExt
#   ✓ ImageMetadata
#   ✓ ImageContrastAdjustment
#   ✓ StrideArraysCore
#   ✓ VectorizationBase
#   ✓ Gridap
#   ✓ PlotlyJS → IJuliaExt
#   ✓ SimpleRandom
#   ✓ MonteCarloIntegration
#   ✓ ScientificTypes
#   ✓ Plots
#   ✓ KernelDensity
#   ✓ Polyester
#   ✓ Netpbm
#   ✓ MathOptInterface
#   ✓ SLEEFPirates
#   ✓ Integrals
#   ✓ CategoricalDistributions
#   ✓ Plotly
#   ✓ FastBroadcast
#   ✓ ImageFiltering
#   ✓ Plots → FileIOExt
#   ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#   ✓ ImageIO
#   ✓ Gadfly
#   ✓ Optim
#   ✓ Integrals → IntegralsForwardDiffExt
#   ✓ Ipopt
#   ✓ MLJModels
#   ✓ FEniCS
#   ✓ MLJBase
#   ✓ DiffEqBase
#   ✓ JuMP
#   ✓ SimpleGraphs
#   ✓ Plots → UnitfulExt
#   ✓ ImageCorners
#   ✓ MLJIteration
#   ✓ LoopVectorization
#   ✓ MLJTuning
#   ✓ MLJEnsembles
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ DelaunayTriangulation
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ MLJ
#   ✓ Plots → GeometryBasicsExt
#   ✓ TriangularSolve
#   ✓ ImageMorphology
#   ✓ JumpProcesses
#   ✓ DiffEqCallbacks
#   ✓ SciMLNLSolve
#   ✓ SimpleNonlinearSolve
#   ✓ Plots → IJuliaExt
#   ✓ Sundials
#   ✓ DiffEqNoiseProcess
#   ✓ ImageDistances
#   ✓ RecursiveFactorization
#   ✓ ImageSegmentation
#   ✓ JumpProcesses → JumpProcessFastBroadcastExt
#   ✓ SteadyStateDiffEq
#   ✓ ImageQualityIndexes
#   ✓ Images
#   ✓ LinearSolve
#   ✓ NonlinearSolve
#   ✓ BoundaryValueDiffEq
#   ✓ Makie
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✗ Eikonal
#   ✓ GLMakie
#   ✓ DifferentialEquations
#   278 dependencies successfully precompiled in 983 seconds. 291 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   1 dependency errored. To see a full report either run `import Pkg; Pkg.precompile()` or load the package
#   5 dependencies had output during precompilation:
# ┌ MKL_jll [856f044c-d86e-5d09-b602-aeab76dc8ba7]
# │   Downloading artifact: MKL
# └
# ┌ Integrals [de52edbc-65ea-441a-8357-d3a637375a31]
# │  WARNING: Method definition solve(SciMLBase.IntegralProblem{isinplace, P, F, B, K} where K where B where F where P where isinplace) in module Integrals at C:\Users\Miguel\.julia\packages\Integrals\leYds\src\Integrals.jl:60 overwritten at C:\Users\Miguel\.julia\packages\Integrals\leYds\src\Integrals.jl:111.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ IntegralsForwardDiffExt [5059dfb8-aee1-58dd-a26b-c87160291a56]
# │  WARNING: Method definition solve(SciMLBase.IntegralProblem{isinplace, P, F, B, K} where K where B where F where P where isinplace) in module Integrals at C:\Users\Miguel\.julia\packages\Integrals\leYds\src\Integrals.jl:111 overwritten at C:\Users\Miguel\.julia\packages\Integrals\leYds\src\Integrals.jl:60.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ DistributionsTestExt [ffbe0ea5-a612-5ff7-aaf5-cac02eef3019]
# │  ┌ Warning: Module DistributionsTestExt with build ID ffffffff-ffff-ffff-0005-2642ca232c8d is missing from the cache.
# │  │ This may mean DistributionsTestExt [ffbe0ea5-a612-5ff7-aaf5-cac02eef3019] does not support precompilation but is imported by a module that does.
# │  └ @ Base loading.jl:1793
# │  ┌ Error: Error during loading of extension DistributionsTestExt of Distributions, use `Base.retry_load_extensions()` to retry.
# │  │   exception =
# │  │    1-element ExceptionStack:
# │  │    Declaring __precompile__(false) is not allowed in files that are being precompiled.
# │  │    Stacktrace:
# │  │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │  │        @ Base .\loading.jl:1797
# │  │      [2] _require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │  │        @ Base .\loading.jl:1660
# │  │      [3] _require_prelocked(uuidkey::Base.PkgId)
# │  │        @ Base .\loading.jl:1658
# │  │      [4] run_extension_callbacks(extid::Base.ExtensionId)
# │  │        @ Base .\loading.jl:1255
# │  │      [5] run_extension_callbacks(pkgid::Base.PkgId)
# │  │        @ Base .\loading.jl:1290
# │  │      [6] run_package_callbacks(modkey::Base.PkgId)
# │  │        @ Base .\loading.jl:1124
# │  │      [7] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │  │        @ Base .\loading.jl:1667
# │  │      [8] macro expansion
# │  │        @ .\loading.jl:1648 [inlined]
# │  │      [9] macro expansion
# │  │        @ .\lock.jl:267 [inlined]
# │  │     [10] require(into::Module, mod::Symbol)
# │  │        @ Base .\loading.jl:1611
# │  │     [11] include
# │  │        @ .\Base.jl:457 [inlined]
# │  │     [12] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │  │        @ Base .\loading.jl:2049
# │  │     [13] top-level scope
# │  │        @ stdin:3
# │  │     [14] eval
# │  │        @ .\boot.jl:370 [inlined]
# │  │     [15] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │  │        @ Base .\loading.jl:1903
# │  │     [16] include_string
# │  │        @ .\loading.jl:1913 [inlined]
# │  │     [17] exec_options(opts::Base.JLOptions)
# │  │        @ Base .\client.jl:305
# │  │     [18] _start()
# │  │        @ Base .\client.jl:522
# │  └ @ Base loading.jl:1261
# └
# ┌ FEniCS [186dfeec-b415-5c13-8e76-5fbf19f56f9b]
# │  [ Info: Installing mshr via the Conda mshr=2019.1.0 package...
# │  [ Info: Running `conda config --add channels conda-forge --file 'C:\Users\Miguel\.julia\conda\3\x86_64\condarc-julia.yml' --force` in root environment
# 39mWarning: 'conda-forge' already in 'channels' list, moving to the top
# │  [ Info: Running `conda install -y mshr=2019.1.0` in root environment
# 39m
# 39mPackagesNotFoundError: The following packages are not available from current channels:
# 39m
# 39m  - mshr=2019.1.0
# 39m
# 39mCurrent channels:
# 39m
# 39m  - https://conda.anaconda.org/conda-forge/win-64
# 39m  - https://conda.anaconda.org/conda-forge/noarch
# 39m  - https://repo.anaconda.com/pkgs/main/win-64
# 39m  - https://repo.anaconda.com/pkgs/main/noarch
# 39m  - https://repo.anaconda.com/pkgs/r/win-64
# 39m  - https://repo.anaconda.com/pkgs/r/noarch
# 39m  - https://repo.anaconda.com/pkgs/msys2/win-64
# 39m  - https://repo.anaconda.com/pkgs/msys2/noarch
# 39m
# 39mTo search for alternate channels that may provide the conda package you're
# 39mlooking for, navigate to
# 39m
# 39m    https://anaconda.org
# 39m
# 39mand use the search bar at the top of the page.
# 39m
# 39m
# │  WARNING: Method definition lvsolve(Any, Any, Any) in module FEniCS at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:11 overwritten at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:18.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(FEniCS.lvsolve), Any, Any, Any) in module FEniCS at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:11 overwritten at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:18.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition nlvsolve(Any, Any) in module FEniCS at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:39 overwritten at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:45.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(FEniCS.nlvsolve), Any, Any) in module FEniCS at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:39 overwritten at C:\Users\Miguel\.julia\packages\FEniCS\rTZFH\src\jsolve.jl:45.
# │    ** incremental compilation may be fatally broken for this module **
# └

# %%
using CSV, DataFrames, MLJ

# Cargar los datos
df = CSV.read("C:\\Users\\Miguel\\Desktop\\TFM\\Recopilación_Datos.txt", DataFrame)
println(names(df))
# Out:
# ["Source_X(m)", "Source_Y(m)", "Source_Z(m)", "Delta_X(m)", "Delta_Y(m)", "Delta_Z(m)", "w_x(m/s)", "w_y(m/s)", "w_z(m/s)", "T(ºC)", "Phi_línea_recta(º)", "Phi_real(º)", "Delta_Phi(º)", "Theta_línea_recta(º)", "Theta_real(º)", "Delta_Theta(º)", "Error_Relativo(%)"]

# %%
#Hacerlo para modelo que soporte pesos
# Convertir el error relativo a pesos
df."ValidezFilas" = 1 .- df."Error_Relativo(%)" ./ 100

# Eliminar las columnas redundantes. 
#select!(df, Not([:"T(ºC)",:"w_x(m/s)",:"w_y(m/s)",:"w_z(m/s)",:"Phi_línea_recta(º)", :"Error_Relativo(%)", :"Theta_línea_recta(º)"]))
select!(df, Not([:"Phi_línea_recta(º)", :"Error_Relativo(%)", :"Theta_línea_recta(º)"]))
# Out:
# 172×15 DataFrame
#  Row │ Source_X(m)  Source_Y(m)  Source_Z(m)  Delta_X(m)  Delta_Y(m)  Delta_Z( ⋯
#      │ Float64      Float64      Float64      Float64     Float64     Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   9887.0         9161.0      4542.0    -5821.0      -1918.0       359.0 ⋯
#    2 │   8821.0         3914.0      5791.0     -324.0       2847.0     -1893.0
#    3 │    790.0         1100.0      7589.0     1034.0         36.0       521.0
#    4 │   6741.0         7116.0      7254.0     -466.0       2644.0     -3013.0
#    5 │   9510.0         8714.0      2331.0    -2413.0      -5550.0     -1591.0 ⋯
#    6 │   8777.0         1157.0      1200.0    -5071.0       5979.0      4667.0
#    7 │   9575.0         4578.0      1617.0    -4042.0      -1937.0      4341.0
#    8 │   9789.0          364.0      3751.0    -2693.0        615.0      1618.0
#    9 │   3042.0         7948.0       649.0     4409.0       -270.0      1629.0 ⋯
#   10 │   1048.0          949.0      8292.0     2506.0       2055.0     -3468.0
#   11 │    288.0         9864.0      1834.0      -10.0      -8809.0      5910.0
#   ⋮  │      ⋮            ⋮            ⋮           ⋮           ⋮           ⋮    ⋱
#  163 │   1799.68        1307.66     4643.73    3182.05      1487.08    -4216.7
#  164 │   6027.17        9252.43     1674.0    -2919.79     -4635.11     3612.5 ⋯
#  165 │   7158.05        1340.14     5558.51    2281.9       3662.59     2893.2
#  166 │    582.863       5475.14     9250.92     555.771    -1211.3     -3611.3
#  167 │   9703.94        7593.82     5657.62   -6335.61     -4964.47      440.0
#  168 │   9082.42        7409.68     4629.85   -8297.77       658.454    4834.9 ⋯
#  169 │   3377.78        1362.39     7067.28    4713.97      5181.05     -266.8
#  170 │   2892.52        4767.56      345.075  -2176.96       432.254     397.6
#  171 │   3304.45        3852.98      695.318    896.749    -1238.86     7621.0
#  172 │   1851.95        8609.29     2764.93    1990.41     -8198.38     5156.6 ⋯
#                                                  10 columns and 151 rows omitted

# %% [markdown]
# Primero para Delta_Theta

# %%
using MLJ

# Definir las columnas de destino
target_cols_1 = [ :"Delta_Theta(º)"]
ex_cols= [ :"ValidezFilas"]
# Definir las columnas de entrada (todas las columnas que no son de destino)
input_cols_1 = setdiff(names(df), target_cols_1)

# Excluir la columna 'ValidezFilas' de las columnas de entrada
input_cols_1 = setdiff(input_cols_1,ex_cols )

# Seleccionar manualmente las columnas de entrada y de destino
X = select(df, input_cols_1)
y = select(df, target_cols_1)

# Dividir los datos en conjuntos de entrenamiento y prueba
train, test = partition(1:nrow(df), 0.7, shuffle=true) # 70% para entrenamiento
# Out:
# ([52, 122, 139, 102, 153, 65, 169, 55, 121, 137  …  167, 18, 125, 22, 152, 59, 44, 80, 134, 46], [15, 17, 47, 135, 116, 73, 98, 5, 147, 170  …  61, 16, 8, 123, 10, 154, 68, 60, 112, 64])

# %%
using MLJ, GLM , MLJGLMInterface
# Seleccionar el modelo
model = @load LinearRegressor pkg=GLM

# Crear una instancia del modelo
model_instance = LinearRegressor()
# Out:
# import MLJGLMInterface ✔
# [ Info: For silent loading, specify `verbosity=0`.
# LinearRegressor(
#   fit_intercept = true,
#   dropcollinear = false,
#   offsetcol = nothing,
#   report_keys = [:deviance, :dof_residual, :stderror, :vcov, :coef_table])

# %%
using GLM, MLJ
# Convertir 'y' a un vector unidimensional
y_vector = Vector{Float64}(y[!, 1])

# Entrenar el modelo
mach = machine(model_instance, X[train, :], y_vector[train])
fit!(mach)

# Evaluar el modelo
y_pred = MLJ.predict(mach, X[test, :])
# Out:
# [ Info: Training machine(LinearRegressor(fit_intercept = true, …), …).
# 52-element Vector{Normal{Float64}}:
#  Normal{Float64}(μ=0.6188584351723111, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.3593881073941403, σ=1.2860465066559517)
#  Normal{Float64}(μ=-1.0236123507793076, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.1559080486353976, σ=1.2860465066559517)
#  Normal{Float64}(μ=2.3348624121301356, σ=1.2860465066559517)
#  Normal{Float64}(μ=3.2709280883816643, σ=1.2860465066559517)
#  Normal{Float64}(μ=4.71263421441663, σ=1.2860465066559517)
#  Normal{Float64}(μ=-0.8147229433898175, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.9289937223737925, σ=1.2860465066559517)
#  Normal{Float64}(μ=4.310272382629265, σ=1.2860465066559517)
#  Normal{Float64}(μ=3.6312882572058665, σ=1.2860465066559517)
#  Normal{Float64}(μ=5.535914501492529, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.6254365754881301, σ=1.2860465066559517)
#  ⋮
#  Normal{Float64}(μ=3.911885390762526, σ=1.2860465066559517)
#  Normal{Float64}(μ=3.6487837579010365, σ=1.2860465066559517)
#  Normal{Float64}(μ=5.423694938497659, σ=1.2860465066559517)
#  Normal{Float64}(μ=-0.9303019336461738, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.0172493099692643, σ=1.2860465066559517)
#  Normal{Float64}(μ=0.2766227814062804, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.7066492983199963, σ=1.2860465066559517)
#  Normal{Float64}(μ=4.409305737112018, σ=1.2860465066559517)
#  Normal{Float64}(μ=0.9912637582776878, σ=1.2860465066559517)
#  Normal{Float64}(μ=-0.0025869277018735204, σ=1.2860465066559517)
#  Normal{Float64}(μ=1.387823263132124, σ=1.2860465066559517)
#  Normal{Float64}(μ=3.2199851025675708, σ=1.2860465066559517)

# %%
using Distributions
# Extraer las medias y las desviaciones estándar de las distribuciones normales
y_pred_means = mean.(y_pred)
y_pred_stds = std.(y_pred);

# Calcular el MSE
mse = mean((y_pred_means .- y_vector[test]).^2)
println("Error cuadrático medio para $target_cols_1: $mse")
# Out:
# Error cuadrático medio para ["Delta_Theta(º)"]: 1.6390619977792757

# %% [markdown]
# Dado que delta_theta es de este orden no parece predecir nada el modelo. Veamos otro.

# %%
using MLJ, MLJMultivariateStatsInterface
model_2 = @load RidgeRegressor pkg=MultivariateStats
model_instance_2 = RidgeRegressor(lambda = 0.5)
# Out:
# import MLJMultivariateStatsInterface ✔
# [ Info: For silent loading, specify `verbosity=0`.
# RidgeRegressor(
#   lambda = 0.5,
#   bias = true)

# %%
using GLM, MLJ
# Convertir 'y' a un vector unidimensional
y_vector = Vector{Float64}(y[!, 1])

# Entrenar el modelo
mach = machine(model_instance_2, X[train, :], y_vector[train])
fit!(mach)

# Evaluar el modelo
y_pred = MLJ.predict(mach, X[test, :])
mse = mean((y_pred .- y_vector[test]).^2)
println("Error cuadrático medio para $target_cols_1: $mse")
# Out:
# Error cuadrático medio para ["Delta_Theta(º)"]: 1.632420304777571
# [ Info: Training machine(RidgeRegressor(lambda = 0.5, …), …).
